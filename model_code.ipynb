# %%
import pandas as pd

# %%
df = pd.read_csv('car data.csv')

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type
# 0       ritz  2014           3.35           5.59       27000    Petrol  \
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type
# 0     ritz  2014           3.35           5.59       27000    Petrol  \
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]

# %%
##check missing or null values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type
# 0       ritz  2014           3.35           5.59       27000    Petrol  \
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]>

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
 df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_dataset=df[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type
# 0  2014           3.35           5.59       27000    Petrol      Dealer  \
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
final_dataset['Current_year']=2020

# %%
final_dataset['no_year'] = final_dataset['Current_year'] - final_dataset['Year']

# %%
final_dataset
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type
# 0    2014           3.35           5.59       27000    Petrol      Dealer  \
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Current_year  no_year
# 0         Manual      0          2020        6
# 1         Manual      0          2020        7
# 2         Manual      0          2020        3
# 3         Manual      0          2020        9
# 4         Manual      0          2020        6
# ..           ...    ...           ...      ...
# 296       Manual      0          2020        4
# 297       Manual      0          2020        5
# 298       Manual      0          2020       11
# 299       Manual      0          2020        3
# 300       Manual      0          2020        4
#
# [301 rows x 10 columns]

# %%
 final_dataset.drop(['Year'],axis=1,inplace=True)

# %%
final_dataset.drop(['Current_year'],axis=1,inplace=True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type
# 0           3.35           5.59       27000    Petrol      Dealer  \
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  no_year
# 0       Manual      0        6
# 1       Manual      0        7
# 2       Manual      0        3
# 3       Manual      0        9
# 4       Manual      0        6

# %%
final_dataset=pd.get_dummies(final_dataset,drop_first=True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  no_year  Fuel_Type_Diesel
# 0           3.35           5.59       27000      0        6             False  \
# 1           4.75           9.54       43000      0        7              True
# 2           7.25           9.85        6900      0        3             False
# 3           2.85           4.15        5200      0        9             False
# 4           4.60           6.87       42450      0        6              True
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0              True                   False                 True
# 1             False                   False                 True
# 2              True                   False                 True
# 3              True                   False                 True
# 4             False                   False                 True

# %%
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner
# Selling_Price                1.000000       0.878983    0.029187 -0.088344  \
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# no_year                     -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                          no_year  Fuel_Type_Diesel  Fuel_Type_Petrol
# Selling_Price          -0.236141          0.552339         -0.540571  \
# Present_Price           0.047584          0.473306         -0.465244
# Kms_Driven              0.524342          0.172515         -0.172874
# Owner                   0.182104         -0.053469          0.055687
# no_year                 1.000000         -0.064315          0.059959
# Fuel_Type_Diesel       -0.064315          1.000000         -0.979648
# Fuel_Type_Petrol        0.059959         -0.979648          1.000000
# Seller_Type_Individual  0.039896         -0.350467          0.358321
# Transmission_Manual    -0.000394         -0.098643          0.091013
#
#                         Seller_Type_Individual  Transmission_Manual
# Selling_Price                        -0.550724            -0.367128
# Present_Price                        -0.512030            -0.348715
# Kms_Driven                           -0.101419            -0.162510
# Owner                                 0.124269            -0.050316
# no_year                               0.039896            -0.000394
# Fuel_Type_Diesel                     -0.350467            -0.098643
# Fuel_Type_Petrol                      0.358321             0.091013
# Seller_Type_Individual                1.000000             0.063240
# Transmission_Manual                   0.063240             1.000000

# %%
conda install seaborn
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.3.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/vinayvuppala/anaconda3/envs/car-prediction
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.0.9               |       hb7f2c08_8          19 KB  conda-forge
#     brotli-bin-1.0.9           |       hb7f2c08_8          17 KB  conda-forge
#     brotlipy-0.7.0             |py39ha30fb19_1005         368 KB  conda-forge
#     cffi-1.15.1                |   py39h131948b_3         214 KB  conda-forge
#     charset-normalizer-3.1.0   |     pyhd8ed1ab_0          44 KB  conda-forge
#     contourpy-1.0.7            |   py39h92daf61_0         204 KB  conda-forge
#     cryptography-40.0.1        |   py39hbeae22c_0         1.1 MB  conda-forge
#     cycler-0.11.0              |     pyhd8ed1ab_0          10 KB  conda-forge
#     fonttools-4.39.3           |   py39ha30fb19_0         2.0 MB  conda-forge
#     freetype-2.12.1            |       h3f81eb7_1         586 KB  conda-forge
#     idna-3.4                   |     pyhd8ed1ab_0          55 KB  conda-forge
#     importlib-resources-5.12.0 |     pyhd8ed1ab_0           9 KB  conda-forge
#     importlib_resources-5.12.0 |     pyhd8ed1ab_0          30 KB  conda-forge
#     kiwisolver-1.4.4           |   py39h92daf61_1          63 KB  conda-forge
#     lcms2-2.15                 |       h2dcdeff_1         222 KB  conda-forge
#     lerc-4.0.0                 |       hb486fe8_0         284 KB  conda-forge
#     libbrotlicommon-1.0.9      |       hb7f2c08_8          64 KB  conda-forge
#     libbrotlidec-1.0.9         |       hb7f2c08_8          33 KB  conda-forge
#     libbrotlienc-1.0.9         |       hb7f2c08_8         303 KB  conda-forge
#     libdeflate-1.18            |       hac1461d_0          65 KB  conda-forge
#     libjpeg-turbo-2.1.5.1      |       hb7f2c08_0         448 KB  conda-forge
#     libpng-1.6.39              |       ha978bb4_0         265 KB  conda-forge
#     libtiff-4.5.0              |       hedf67fa_6         384 KB  conda-forge
#     libwebp-base-1.3.0         |       hb7f2c08_0         338 KB  conda-forge
#     libxcb-1.13                |    h0d85af4_1004         305 KB  conda-forge
#     matplotlib-base-3.7.1      |   py39hb2f573b_0         6.3 MB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     openjpeg-2.5.0             |       h13ac156_2         322 KB  conda-forge
#     packaging-23.0             |     pyhd8ed1ab_0          40 KB  conda-forge
#     patsy-0.5.3                |     pyhd8ed1ab_0         189 KB  conda-forge
#     pillow-9.5.0               |   py39h77c96bc_0        43.5 MB  conda-forge
#     platformdirs-3.2.0         |     pyhd8ed1ab_0          17 KB  conda-forge
#     pooch-1.7.0                |     pyha770c72_3          50 KB  conda-forge
#     pthread-stubs-0.4          |    hc929b4f_1001           6 KB  conda-forge
#     pycparser-2.21             |     pyhd8ed1ab_0         100 KB  conda-forge
#     pyopenssl-23.1.1           |     pyhd8ed1ab_0         125 KB  conda-forge
#     pysocks-1.7.1              |     pyha2e5f31_6          19 KB  conda-forge
#     requests-2.28.2            |     pyhd8ed1ab_1          56 KB  conda-forge
#     scipy-1.10.1               |   py39h8a15683_0        20.5 MB  conda-forge
#     seaborn-0.12.2             |       hd8ed1ab_0           6 KB  conda-forge
#     seaborn-base-0.12.2        |     pyhd8ed1ab_0         226 KB  conda-forge
#     statsmodels-0.13.5         |   py39h7cc1f47_2        10.7 MB  conda-forge
#     unicodedata2-15.0.0        |   py39ha30fb19_0         486 KB  conda-forge
#     urllib3-1.26.15            |     pyhd8ed1ab_0         110 KB  conda-forge
#     xorg-libxau-1.0.9          |       h35c211d_0          11 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h35c211d_0          17 KB  conda-forge
#     zipp-3.15.0                |     pyhd8ed1ab_0          17 KB  conda-forge
#     zstd-1.5.2                 |       hbc0c0cd_6         399 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        90.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/osx-64::brotli-1.0.9-hb7f2c08_8
#   brotli-bin         conda-forge/osx-64::brotli-bin-1.0.9-hb7f2c08_8
#   brotlipy           conda-forge/osx-64::brotlipy-0.7.0-py39ha30fb19_1005
#   certifi            conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   cffi               conda-forge/osx-64::cffi-1.15.1-py39h131948b_3
#   charset-normalizer conda-forge/noarch::charset-normalizer-3.1.0-pyhd8ed1ab_0
#   contourpy          conda-forge/osx-64::contourpy-1.0.7-py39h92daf61_0
#   cryptography       conda-forge/osx-64::cryptography-40.0.1-py39hbeae22c_0
#   cycler             conda-forge/noarch::cycler-0.11.0-pyhd8ed1ab_0
#   fonttools          conda-forge/osx-64::fonttools-4.39.3-py39ha30fb19_0
#   freetype           conda-forge/osx-64::freetype-2.12.1-h3f81eb7_1
#   idna               conda-forge/noarch::idna-3.4-pyhd8ed1ab_0
#   importlib-resourc~ conda-forge/noarch::importlib-resources-5.12.0-pyhd8ed1ab_0
#   importlib_resourc~ conda-forge/noarch::importlib_resources-5.12.0-pyhd8ed1ab_0
#   kiwisolver         conda-forge/osx-64::kiwisolver-1.4.4-py39h92daf61_1
#   lcms2              conda-forge/osx-64::lcms2-2.15-h2dcdeff_1
#   lerc               conda-forge/osx-64::lerc-4.0.0-hb486fe8_0
#   libbrotlicommon    conda-forge/osx-64::libbrotlicommon-1.0.9-hb7f2c08_8
#   libbrotlidec       conda-forge/osx-64::libbrotlidec-1.0.9-hb7f2c08_8
#   libbrotlienc       conda-forge/osx-64::libbrotlienc-1.0.9-hb7f2c08_8
#   libdeflate         conda-forge/osx-64::libdeflate-1.18-hac1461d_0
#   libjpeg-turbo      conda-forge/osx-64::libjpeg-turbo-2.1.5.1-hb7f2c08_0
#   libpng             conda-forge/osx-64::libpng-1.6.39-ha978bb4_0
#   libtiff            conda-forge/osx-64::libtiff-4.5.0-hedf67fa_6
#   libwebp-base       conda-forge/osx-64::libwebp-base-1.3.0-hb7f2c08_0
#   libxcb             conda-forge/osx-64::libxcb-1.13-h0d85af4_1004
#   matplotlib-base    conda-forge/osx-64::matplotlib-base-3.7.1-py39hb2f573b_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   openjpeg           conda-forge/osx-64::openjpeg-2.5.0-h13ac156_2
#   packaging          conda-forge/noarch::packaging-23.0-pyhd8ed1ab_0
#   patsy              conda-forge/noarch::patsy-0.5.3-pyhd8ed1ab_0
#   pillow             conda-forge/osx-64::pillow-9.5.0-py39h77c96bc_0
#   platformdirs       conda-forge/noarch::platformdirs-3.2.0-pyhd8ed1ab_0
#   pooch              conda-forge/noarch::pooch-1.7.0-pyha770c72_3
#   pthread-stubs      conda-forge/osx-64::pthread-stubs-0.4-hc929b4f_1001
#   pycparser          conda-forge/noarch::pycparser-2.21-pyhd8ed1ab_0
#   pyopenssl          conda-forge/noarch::pyopenssl-23.1.1-pyhd8ed1ab_0
#   pyparsing          conda-forge/noarch::pyparsing-3.0.9-pyhd8ed1ab_0
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyha2e5f31_6
#   requests           conda-forge/noarch::requests-2.28.2-pyhd8ed1ab_1
#   scipy              conda-forge/osx-64::scipy-1.10.1-py39h8a15683_0
#   seaborn            conda-forge/noarch::seaborn-0.12.2-hd8ed1ab_0
#   seaborn-base       conda-forge/noarch::seaborn-base-0.12.2-pyhd8ed1ab_0
#   statsmodels        conda-forge/osx-64::statsmodels-0.13.5-py39h7cc1f47_2
#   typing-extensions  conda-forge/noarch::typing-extensions-4.5.0-hd8ed1ab_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.5.0-pyha770c72_0
#   unicodedata2       conda-forge/osx-64::unicodedata2-15.0.0-py39ha30fb19_0
#   urllib3            conda-forge/noarch::urllib3-1.26.15-pyhd8ed1ab_0
#   xorg-libxau        conda-forge/osx-64::xorg-libxau-1.0.9-h35c211d_0
#   xorg-libxdmcp      conda-forge/osx-64::xorg-libxdmcp-1.1.3-h35c211d_0
#   zipp               conda-forge/noarch::zipp-3.15.0-pyhd8ed1ab_0
#   zstd               conda-forge/osx-64::zstd-1.5.2-hbc0c0cd_6
#
#
#
# Downloading and Extracting Packages
# patsy-0.5.3          | 189 KB    |                                       |   0%
# fonttools-4.39.3     | 2.0 MB    |                                       |   0%
#
# xorg-libxdmcp-1.1.3  | 17 KB     |                                       |   0%
#
#
# openjpeg-2.5.0       | 322 KB    |                                       |   0%
#
#
#
# brotli-bin-1.0.9     | 17 KB     |                                       |   0%
#
#
#
#
# pysocks-1.7.1        | 19 KB     |                                       |   0%
#
#
#
#
#
# importlib_resources- | 30 KB     |                                       |   0%
#
#
#
#
#
#
# brotli-1.0.9         | 19 KB     |                                       |   0%
#
#
#
#
#
#
#
# contourpy-1.0.7      | 204 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# matplotlib-base-3.7. | 6.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# brotlipy-0.7.0       | 368 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.3.0   | 338 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# importlib-resources- | 9 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# idna-3.4             | 55 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.0. | 64 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 33 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 20.5 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.13          | 305 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munkres-1.1.4        | 12 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.2           | 399 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# statsmodels-0.13.5   | 10.7 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# charset-normalizer-3 | 44 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 284 KB    |                                       |   0%
# patsy-0.5.3          | 189 KB    | ###1                                  |   8% [A
#
#
#
#
# patsy-0.5.3          | 189 KB    | ##################################### | 100%
#
#
#
#
# pysocks-1.7.1        | 19 KB     | ##################################### | 100%
#
#
# openjpeg-2.5.0       | 322 KB    | #8                                    |   5%
#
#
#
# brotli-bin-1.0.9     | 17 KB     | ##################################1   |  92%
#
# xorg-libxdmcp-1.1.3  | 17 KB     | ###################################1  |  95%
#
#
#
#
#
# importlib_resources- | 30 KB     | ###################5                  |  53%
#
# xorg-libxdmcp-1.1.3  | 17 KB     | ##################################### | 100%
#
#
#
# brotli-bin-1.0.9     | 17 KB     | ##################################### | 100%
#
#
#
#
#
# importlib_resources- | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
# brotli-1.0.9         | 19 KB     | ###############################9      |  86%
#
#
#
#
#
#
# brotli-1.0.9         | 19 KB     | ##################################### | 100%
#
#
# openjpeg-2.5.0       | 322 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.3.0   | 338 KB    | #7                                    |   5%
#
#
#
#
#
#
#
#
#
# brotlipy-0.7.0       | 368 KB    | #6                                    |   4%
# fonttools-4.39.3     | 2.0 MB    | 2                                     |   1%
#
#
#
#
#
#
#
# contourpy-1.0.7      | 204 KB    | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.3.0   | 338 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# importlib-resources- | 9 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# importlib-resources- | 9 KB      | ##################################### | 100%
#
#
#
#
#
#
#
# contourpy-1.0.7      | 204 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# idna-3.4             | 55 KB     | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
# brotlipy-0.7.0       | 368 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# brotlipy-0.7.0       | 368 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# idna-3.4             | 55 KB     | ##################################### | 100%
# fonttools-4.39.3     | 2.0 MB    | ####6                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 33 KB     | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 33 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# matplotlib-base-3.7. | 6.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 20.5 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.13          | 305 KB    | #9                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.0. | 64 KB     | #########2                            |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.0. | 64 KB     | ##################################### | 100%
# fonttools-4.39.3     | 2.0 MB    | ########################2             |  66%
#
#
#
#
#
#
#
#
# matplotlib-base-3.7. | 6.3 MB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 20.5 MB   | #####7                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munkres-1.1.4        | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munkres-1.1.4        | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.13          | 305 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.13          | 305 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.2           | 399 KB    | #4                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.2           | 399 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# charset-normalizer-3 | 44 KB     | #############4                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 20.5 MB   | #############6                        |  37%
#
#
#
#
#
#
#
#
# matplotlib-base-3.7. | 6.3 MB    | ####2                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# charset-normalizer-3 | 44 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# statsmodels-0.13.5   | 10.7 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 284 KB    | ##                                    |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 284 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 20.5 MB   | ######################2               |  60%
#
#
#
#
#
#
#
#
# matplotlib-base-3.7. | 6.3 MB    | #########                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# statsmodels-0.13.5   | 10.7 MB   | ###4                                  |   9%
# fonttools-4.39.3     | 2.0 MB    | ##################################### | 100%
# fonttools-4.39.3     | 2.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 20.5 MB   | ############################9         |  78%
#
#
#
#
#
#
#
#
# matplotlib-base-3.7. | 6.3 MB    | ##############                        |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# statsmodels-0.13.5   | 10.7 MB   | ########                              |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 20.5 MB   | ###################################7  |  97%
#
#
#
#
#
#
#
#
# matplotlib-base-3.7. | 6.3 MB    | ##################7                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# statsmodels-0.13.5   | 10.7 MB   | ############2                         |  33%
#
#
#
#
#
#
#
#
# matplotlib-base-3.7. | 6.3 MB    | ######################7               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# statsmodels-0.13.5   | 10.7 MB   | ###############8                      |  43%
#
#
#
#
#
#
#
#
# matplotlib-base-3.7. | 6.3 MB    | ###########################9          |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# statsmodels-0.13.5   | 10.7 MB   | ###################7                  |  53%
#
#
#
#
#
#
#
#
# matplotlib-base-3.7. | 6.3 MB    | ################################8     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# statsmodels-0.13.5   | 10.7 MB   | ########################5             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# statsmodels-0.13.5   | 10.7 MB   | #############################         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# statsmodels-0.13.5   | 10.7 MB   | #################################5    |  91%
#
#
#
#
#
#
#
#
# matplotlib-base-3.7. | 6.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 20.5 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# statsmodels-0.13.5   | 10.7 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
corrmat=final_dataset.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g= sns.heatmap(final_dataset[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
X=final_dataset.iloc[:,1:]
Y=final_dataset.iloc[:,0]

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Owner  no_year  Fuel_Type_Diesel
# 0           5.59       27000      0        6             False  \
# 1           9.54       43000      0        7              True
# 2           9.85        6900      0        3             False
# 3           4.15        5200      0        9             False
# 4           6.87       42450      0        6              True
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0              True                   False                 True
# 1             False                   False                 True
# 2              True                   False                 True
# 3              True                   False                 True
# 4             False                   False                 True

# %%
Y.head()
# Out:
# 0    3.35
# 1    4.75
# 2    7.25
# 3    2.85
# 4    4.60
# Name: Selling_Price, dtype: float64

# %%
import sklearn
from sklearn.ensemble import ExtraTreesRegressor

# %%
model=ExtraTreesRegressor()
model.fit(X,Y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.35488523 0.0390616  0.00052638 0.07503357 0.24439494 0.01032498
#  0.12588426 0.14988904]

# %%
#plot graph of features importances for better vizualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)

# %%
X_train.shape
# Out:
# (240, 8)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_random = RandomForestRegressor()

# %%
###Hyperparameters
import numpy as np
n_estimators=[int(x) for x in np.linspace(start = 100,stop = 1200,num = 12)]
print(n_estimators)
# Out:
# [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]

# %%
#Randomized Search CV

#Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100,stop = 1200, num = 12)]
#Number of features to consider at every split
max_features = ['auto','sqrt']
#Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5,30,num = 6)]
#Minimum number of samples required to split a node
min_samples_split = [2,5,10,15,100]
#Minimum number of samples required at each leaf node
min_samples_leaf = [2,5,10,15,100]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_grid = {
    'n_estimators' : n_estimators,
    'max_features' : max_features,
    'max_depth' : max_depth,
    'min_samples_split' : min_samples_split,
    'min_samples_leaf' : min_samples_leaf
}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [2, 5, 10, 15, 100]}

# %%
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42,n_jobs=1)

# %%
rf_random.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   0.4s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   0.4s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   0.4s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   0.4s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=10, min_samples_split=100, n_estimators=700; total time=   0.4s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, n_estimators=400; total time=   0.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, n_estimators=400; total time=   0.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, n_estimators=400; total time=   0.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, n_estimators=400; total time=   0.2s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=15, min_samples_split=10, n_estimators=400; total time=   0.2s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=100, min_samples_split=5, n_estimators=900; total time=   0.5s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=100, min_samples_split=5, n_estimators=900; total time=   0.5s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=100, min_samples_split=5, n_estimators=900; total time=   0.5s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=100, min_samples_split=5, n_estimators=900; total time=   0.6s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=100, min_samples_split=5, n_estimators=900; total time=   0.5s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1100; total time=   0.7s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1100; total time=   0.7s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1100; total time=   0.7s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1100; total time=   0.7s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=1100; total time=   0.7s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=100, n_estimators=300; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=100, n_estimators=300; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=100, n_estimators=300; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=100, n_estimators=300; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=100, n_estimators=300; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=400; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=400; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=400; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=400; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=15, min_samples_split=5, n_estimators=400; total time=   0.2s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=900; total time=   0.6s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=900; total time=   0.6s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=900; total time=   0.6s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=900; total time=   0.6s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# [CV] END max_depth=30, max_features=auto, min_samples_leaf=5, min_samples_split=10, n_estimators=900; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time=   0.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time=   0.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time=   0.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time=   0.4s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=5, n_estimators=700; total time=   0.4s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=1000; total time=   0.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=   0.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=   0.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=   0.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=   0.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=1100; total time=   0.6s
# /Users/vinayvuppala/anaconda3/envs/car-prediction/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [2, 5, 10, 15, 100],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
predictions=rf_random.predict(X_test)

# %%
predictions
# Out:
# array([ 6.27599032,  4.31745526,  3.91407559,  0.59563562,  4.89909739,
#         5.86453269,  4.21479788,  4.68488858,  5.65776054,  4.47128035,
#         9.77119389, 11.18182458,  6.60521845,  3.34999125,  0.58374991,
#         3.1107802 ,  4.25845736,  0.57581348,  2.99989178,  3.53737778,
#         7.9596027 ,  4.87961314,  7.03763015,  3.11916749,  0.27886597,
#         2.56365311,  9.14852236,  3.11916749,  5.88099032,  5.1063341 ,
#        21.45752903,  9.91733702,  6.84302864,  8.54718881,  4.67402422,
#         0.49221959,  4.82434964,  0.61978303, 11.61224616,  0.52517321,
#         9.96272574,  0.44990647,  0.43799215,  0.56470718,  4.46446628,
#         4.46717728,  1.73430894,  1.13219495,  0.23197069,  0.49951595,
#         0.45003747,  4.45779722,  0.55786718,  4.12301703,  0.20903644,
#         4.53947341,  0.60975578,  0.33787297,  2.88000865,  7.22056469,
#         3.04657502])

# %%
 sns.distplot(Y_test-predictions)
# Out:
# /var/folders/gs/cv5l1cy51qj4zbcz6zm37y540000gn/T/ipykernel_37911/3918246243.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_test-predictions)
# <Axes: xlabel='Selling_Price', ylabel='Density'>

# %%
plt.scatter(Y_test,predictions)

# %%
import pickle 
#open a file, where you ant to store the data
file=open('random_forest_regression_model.pkl','wb')

#dump information to that file
pickle.dump(rf_random,file)
